# %%
# !pip install mlflow scikit-learn pandas numpy seaborn matplotlib cloudpickle requests
# Out:
# Collecting mlflow
#   Downloading mlflow-3.10.1-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: scikit-learn in c:\users\aryan\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: pandas in c:\users\aryan\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in c:\users\aryan\anaconda3\lib\site-packages (2.4.2)
# Requirement already satisfied: seaborn in c:\users\aryan\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\aryan\anaconda3\lib\site-packages (3.10.8)
# Requirement already satisfied: cloudpickle in c:\users\aryan\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: requests in c:\users\aryan\anaconda3\lib\site-packages (2.32.3)
# Collecting mlflow-skinny==3.10.1 (from mlflow)
#   Downloading mlflow_skinny-3.10.1-py3-none-any.whl.metadata (32 kB)
# Collecting mlflow-tracing==3.10.1 (from mlflow)
#   Downloading mlflow_tracing-3.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow) (1.16.5)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow) (44.0.1)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting huey<3,>=2.5.4 (from mlflow)
#   Downloading huey-2.6.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: pyarrow<24,>=4.0.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow) (19.0.0)
# Requirement already satisfied: scipy<2 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow) (1.17.1)
# Collecting skops<1 (from mlflow)
#   Downloading skops-0.13.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow) (2.0.39)
# Collecting waitress<4 (from mlflow)
#   Downloading waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools<8,>=5.0.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (8.1.8)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.10.1->mlflow)
#   Downloading databricks_sdk-0.99.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.10.1->mlflow)
#   Downloading fastapi-0.135.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (8.5.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.10.1->mlflow)
#   Downloading opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.10.1->mlflow)
#   Downloading opentelemetry_proto-1.40.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.10.1->mlflow)
#   Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<27 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (2.10.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (6.0.2)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.10.1->mlflow)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\aryan\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (4.12.2)
# Collecting uvicorn<1 (from mlflow-skinny==3.10.1->mlflow)
#   Downloading uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\aryan\anaconda3\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\aryan\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aryan\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aryan\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aryan\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aryan\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aryan\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aryan\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aryan\anaconda3\lib\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: Mako in c:\users\aryan\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.2.3)
# Requirement already satisfied: colorama in c:\users\aryan\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.10.1->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\aryan\anaconda3\lib\site-packages (from cryptography<47,>=43.0.0->mlflow) (1.17.1)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow)
#   Downloading google_auth-2.49.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.10.1->mlflow)
#   Downloading protobuf-6.33.5-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: pywin32>=304 in c:\users\aryan\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (308)
# Collecting starlette>=0.46.0 (from fastapi<1->mlflow-skinny==3.10.1->mlflow)
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi<1->mlflow-skinny==3.10.1->mlflow)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.10.1->mlflow)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\aryan\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\aryan\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\aryan\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\aryan\anaconda3\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\aryan\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.10.1->mlflow) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\aryan\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.10.1->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aryan\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow) (0.2.8)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.8-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: zipp>=3.20 in c:\users\aryan\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.10.1->mlflow) (3.21.0)
# Collecting opentelemetry-semantic-conventions==0.61b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.10.1->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aryan\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.1->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\aryan\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.1->mlflow) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\aryan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting prettytable>=3.9 (from skops<1->mlflow)
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\aryan\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: h11>=0.8 in c:\users\aryan\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.10.1->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\aryan\anaconda3\lib\site-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aryan\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: wcwidth in c:\users\aryan\anaconda3\lib\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\aryan\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow) (0.4.8)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\aryan\anaconda3\lib\site-packages (from starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.1->mlflow) (4.7.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aryan\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.1->mlflow) (1.3.0)
# Downloading mlflow-3.10.1-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------  10.0/10.2 MB 78.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 59.2 MB/s eta 0:00:00
# Downloading mlflow_skinny-3.10.1-py3-none-any.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------------------- 3.0/3.0 MB 98.1 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.10.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 74.0 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 11.0/11.0 MB 113.4 MB/s eta 0:00:00
# Downloading databricks_sdk-0.99.0-py3-none-any.whl (829 kB)
#    ---------------------------------------- 0.0/829.5 kB ? eta -:--:--
#    --------------------------------------- 829.5/829.5 kB 49.2 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.135.1-py3-none-any.whl (116 kB)
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Downloading google_auth-2.49.1-py3-none-any.whl (240 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.8-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading huey-2.6.0-py3-none-any.whl (76 kB)
# Downloading opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
# Downloading opentelemetry_proto-1.40.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl (141 kB)
# Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl (231 kB)
# Downloading protobuf-6.33.5-cp310-abi3-win_amd64.whl (437 kB)
# Downloading skops-0.13.0-py3-none-any.whl (131 kB)
# Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Downloading uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: huey, waitress, typing-inspection, sqlparse, protobuf, prettytable, graphql-core, annotated-doc, uvicorn, starlette, pandas, opentelemetry-proto, opentelemetry-api, graphql-relay, docker, skops, opentelemetry-semantic-conventions, graphene, google-auth, Flask-CORS, fastapi, opentelemetry-sdk, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
#
#    ----------------------------------------  0/26 [huey]
#    ---- -----------------------------------  3/26 [sqlparse]
#   Attempting uninstall: protobuf
#    ---- -----------------------------------  3/26 [sqlparse]
#     Found existing installation: protobuf 5.29.3
#    ---- -----------------------------------  3/26 [sqlparse]
#    ------ ---------------------------------  4/26 [protobuf]
#     Uninstalling protobuf-5.29.3:
#    ------ ---------------------------------  4/26 [protobuf]
#       Successfully uninstalled protobuf-5.29.3
#    ------ ---------------------------------  4/26 [protobuf]
#    ------ ---------------------------------  4/26 [protobuf]
#    ------ ---------------------------------  4/26 [protobuf]
#    --------- ------------------------------  6/26 [graphql-core]
#    --------- ------------------------------  6/26 [graphql-core]
#    --------- ------------------------------  6/26 [graphql-core]
#    --------- ------------------------------  6/26 [graphql-core]
#    ------------ ---------------------------  8/26 [uvicorn]
#    ------------- --------------------------  9/26 [starlette]
#   Attempting uninstall: pandas
#    ------------- --------------------------  9/26 [starlette]
#     Found existing installation: pandas 3.0.0
#    ------------- --------------------------  9/26 [starlette]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#     Uninstalling pandas-3.0.0:
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#       Successfully uninstalled pandas-3.0.0
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    --------------- ------------------------ 10/26 [pandas]
#    ---------------- ----------------------- 11/26 [opentelemetry-proto]
#    -------------------- ------------------- 13/26 [graphql-relay]
#    --------------------- ------------------ 14/26 [docker]
#    --------------------- ------------------ 14/26 [docker]
#    ----------------------- ---------------- 15/26 [skops]
#    -------------------- ------------ 16/26 [opentelemetry-semantic-conventions]
#    -------------------- ------------ 16/26 [opentelemetry-semantic-conventions]
#    -------------------- ------------ 16/26 [opentelemetry-semantic-conventions]
#    -------------------------- ------------- 17/26 [graphene]
#    -------------------------- ------------- 17/26 [graphene]
#    --------------------------- ------------ 18/26 [google-auth]
#    --------------------------- ------------ 18/26 [google-auth]
#    --------------------------- ------------ 18/26 [google-auth]
#    ------------------------------ --------- 20/26 [fastapi]
#    ------------------------------ --------- 20/26 [fastapi]
#    -------------------------------- ------- 21/26 [opentelemetry-sdk]
#    --------------------------------- ------ 22/26 [databricks-sdk]
#    --------------------------------- ------ 22/26 [databricks-sdk]
#    --------------------------------- ------ 22/26 [databricks-sdk]
#    --------------------------------- ------ 22/26 [databricks-sdk]
#    --------------------------------- ------ 22/26 [databricks-sdk]
#    --------------------------------- ------ 22/26 [databricks-sdk]
#    --------------------------------- ------ 22/26 [databricks-sdk]
#    --------------------------------- ------ 22/26 [databricks-sdk]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ----------------------------------- ---- 23/26 [mlflow-tracing]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    ------------------------------------ --- 24/26 [mlflow-skinny]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    -------------------------------------- - 25/26 [mlflow]
#    ---------------------------------------- 26/26 [mlflow]
#
# Successfully installed Flask-CORS-6.0.2 annotated-doc-0.0.4 databricks-sdk-0.99.0 docker-7.1.0 fastapi-0.135.1 google-auth-2.49.1 graphene-3.4.3 graphql-core-3.2.8 graphql-relay-3.2.0 huey-2.6.0 mlflow-3.10.1 mlflow-skinny-3.10.1 mlflow-tracing-3.10.1 opentelemetry-api-1.40.0 opentelemetry-proto-1.40.0 opentelemetry-sdk-1.40.0 opentelemetry-semantic-conventions-0.61b0 pandas-2.3.3 prettytable-3.17.0 protobuf-6.33.5 skops-0.13.0 sqlparse-0.5.5 starlette-0.52.1 typing-inspection-0.4.2 uvicorn-0.41.0 waitress-3.0.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red = pd.read_csv("winequality-red.csv", sep=";")
white = pd.read_csv("winequality-white.csv", sep=";")

print(red.shape)
print(white.shape)
# Out:
# (1599, 12)
# (4898, 12)

# %%
red['is_red'] = 1
white['is_red'] = 0

data = pd.concat([red, white], axis=0)

# Remove spaces from column names
data.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
data.head()

data.info()

data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  is_red                6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 710.6 KB
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality       is_red
# count  6497.000000  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378     0.246114
# std       0.160787     0.148806     1.192712     0.873255     0.430779
# min       2.720000     0.220000     8.000000     3.000000     0.000000
# 25%       3.110000     0.430000     9.500000     5.000000     0.000000
# 50%       3.210000     0.510000    10.300000     6.000000     0.000000
# 75%       3.320000     0.600000    11.300000     6.000000     0.000000
# max       4.010000     2.000000    14.900000     9.000000     1.000000

# %%
data.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# is_red                  0
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
data.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# is_red                    int64
# dtype: object

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=data)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="quality", data=data)
plt.show()

# %%
sns.histplot(data["alcohol"], kde=True)
plt.show()

# %%
corr = data.corr(numeric_only=True)

plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
sns.distplot(data.quality, kde=False);
# Out:
# C:\Users\Aryan\AppData\Local\Temp\ipykernel_960\3323878950.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.quality, kde=False);

# %%
high_quality = (data.quality >= 7).astype(int)
data.quality = high_quality

# %%
dims = (3, 4)
f, axes = plt.subplots(dims[0], dims[1], figsize=(25, 15))
axis_i, axis_j = 0, 0

for col in data.columns:
    if col == 'is_red' or col == 'quality':
        continue  # Box plots cannot be used on indicator variables
    sns.boxplot(x=high_quality, y=data[col], ax=axes[axis_i, axis_j])
    axis_j += 1
    if axis_j == dims[1]:
        axis_i += 1
        axis_j = 0

# %%
from sklearn.model_selection import train_test_split

X = data.drop(["quality"], axis=1)
y = data.quality

# Split out the training data
X_train, X_rem, y_train, y_rem = train_test_split(X, y, train_size=0.6, random_state=123)

# Split the remaining data equally into validation and test
X_val, X_test, y_val, y_test = train_test_split(X_rem, y_rem, test_size=0.5, random_state=123)

# %%
import mlflow
import mlflow.pyfunc
import mlflow.sklearn
import numpy as np
import sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from mlflow.models.signature import infer_signature
from mlflow.utils.environment import _mlflow_conda_env
import cloudpickle
import time

# Wrapper to return probability instead of class
class SklearnModelWrapper(mlflow.pyfunc.PythonModel):
    def __init__(self, model):
        self.model = model

    def predict(self, context, model_input):
        return self.model.predict_proba(model_input)[:, 1]


# Start MLflow experiment run
with mlflow.start_run(run_name='decision_tree_model'):

    model = DecisionTreeClassifier(
        max_depth=5,
        random_state=123
    )

    model.fit(X_train, y_train)

    # Predict probabilities for test set
    predictions_test = model.predict_proba(X_test)[:, 1]

    # Compute AUC score
    auc_score = roc_auc_score(y_test, predictions_test)

    # Log parameters and metrics
    mlflow.log_param("model_type", "DecisionTreeClassifier")
    mlflow.log_param("max_depth", 5)
    mlflow.log_metric("auc", auc_score)

    wrappedModel = SklearnModelWrapper(model)

    # Infer model signature
    signature = infer_signature(X_train, wrappedModel.predict(None, X_train))

    # Create conda environment for model deployment
    conda_env = _mlflow_conda_env(
        additional_conda_deps=None,
        additional_pip_deps=[
            "cloudpickle=={}".format(cloudpickle.__version__),
            "scikit-learn=={}".format(sklearn.__version__)
        ],
        additional_conda_channels=None,
    )

    # Log the model
    mlflow.pyfunc.log_model(
        artifact_path="decision_tree_model",
        python_model=wrappedModel,
        conda_env=conda_env,
        signature=signature
    )
# Out:
# C:\Users\Aryan\anaconda3\Lib\site-packages\mlflow\pyfunc\utils\data_validation.py:186: UserWarning: Add type hints to the `predict` method to enable data validation and automatic signature inference during model logging. Check https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage-in-pythonmodel for more details.
#   color_warning(
# C:\Users\Aryan\anaconda3\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2026/03/13 17:38:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/03/13 17:38:13 WARNING mlflow.pyfunc: Passing a Python object as `python_model` causes it to be serialized using CloudPickle, it requires exercising caution as Python object serialization mechanisms may execute arbitrary code during deserialization.Consider using a file path (str or Path) instead. See https://mlflow.org/docs/latest/ml/model/models-from-code/ for details.
# C:\Users\Aryan\anaconda3\Lib\site-packages\mlflow\pyfunc\__init__.py:3304: UserWarning: An input example was not provided when logging the model. To ensure the model signature functions correctly, specify the `input_example` parameter. See https://mlflow.org/docs/latest/model/signatures.html#model-input-example for more details about the benefits of using input_example.
#   color_warning(

# %%
feature_importances = pd.DataFrame(model.feature_importances_, index=X_train.columns.tolist(), columns=['importance'])
feature_importances.sort_values('importance', ascending=False)
# Out:
#                       importance
# alcohol                 0.630100
# sulphates               0.093935
# volatile_acidity        0.076182
# residual_sugar          0.049411
# citric_acid             0.043663
# free_sulfur_dioxide     0.037386
# chlorides               0.026826
# pH                      0.017762
# fixed_acidity           0.012423
# total_sulfur_dioxide    0.012311
# density                 0.000000
# is_red                  0.000000

# %%
run_id = mlflow.search_runs(
    filter_string='tags.mlflow.runName = "decision_tree_model"'
).iloc[0].run_id

model_name = "wine_quality"
model_version = mlflow.register_model(f"runs:/{run_id}/decision_tree_model", model_name)

time.sleep(15)
# Out:
# Registered model 'wine_quality' already exists. Creating a new version of this model...
# 2026/03/13 17:38:22 WARNING mlflow.tracking._model_registry.fluent: Run with id 02b425aabf1649aea5bfea3c08a5d561 has no artifacts at artifact path 'decision_tree_model', registering model based on models:/m-74cc16758da949af9e271b282c61c4a1 instead
# Created version '2' of model 'wine_quality'.

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()
client.transition_model_version_stage(
  name=model_name,
  version=model_version.version,
  stage="Production",
)
# Out:
# C:\Users\Aryan\AppData\Local\Temp\ipykernel_19716\3087969861.py:4: FutureWarning: ``mlflow.tracking.client.MlflowClient.transition_model_version_stage`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   client.transition_model_version_stage(
# <ModelVersion: aliases=[], creation_timestamp=1773374224666, current_stage='Production', deployment_job_state=None, description=None, last_updated_timestamp=1773374243771, metrics=None, model_id=None, name='wine_quality', params=None, run_id='7f05583463494a57a7206f6efc64cee2', run_link=None, source='models:/m-ce648472306841f9893b065aef606a4d', status='READY', status_message=None, tags={}, user_id=None, version=1, workspace='default'>

# %%
model = mlflow.pyfunc.load_model(f"models:/{model_name}/production")

# Sanity-check: This should match the AUC logged by MLflow
print(f'AUC: {roc_auc_score(y_test, model.predict(X_test))}')
# Out:
# AUC: 0.7994963359444993

# %%
import mlflow.pyfunc
import pandas as pd

# Load MLflow model
model = mlflow.pyfunc.load_model(f"models:/{model_name}/Production")

# Load dataset
new_data = pd.read_csv("winequality-red.csv", sep=";")

# Fix column names to match training schema
new_data.columns = new_data.columns.str.replace(" ", "_")

# Remove target column
new_data = new_data.drop(columns=["quality"], errors="ignore")

# Add wine type column expected by model
new_data["is_red"] = 1

# Ensure column order matches model schema
new_data = new_data[
    [
        "fixed_acidity",
        "volatile_acidity",
        "citric_acid",
        "residual_sugar",
        "chlorides",
        "free_sulfur_dioxide",
        "total_sulfur_dioxide",
        "density",
        "pH",
        "sulphates",
        "alcohol",
        "is_red",
    ]
]

# Make predictions
predictions = model.predict(new_data)

# Attach predictions
new_data["prediction"] = predictions

print(new_data.head())
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  is_red  prediction
# 0      9.4       1    0.025575
# 1      9.8       1    0.025575
# 2      9.8       1    0.025575
# 3      9.8       1    0.025575
# 4      9.4       1    0.025575

# %%
type(predictions)
# Out:
# numpy.ndarray

# %%
import requests
import json

url = 'http://localhost:5001/invocations'  # Replace with the actual endpoint URL

data_dict = {"dataframe_split": X_test.to_dict(orient='split')}

response = requests.post(url, json=data_dict)
predictions = response.json()

print(predictions)
# Out:
# {'predictions': [0.02557544757033248, 0.18604651162790697, 0.02557544757033248, 0.027649769585253458, 0.027649769585253458, 0.24338624338624337, 0.537117903930131, 0.18604651162790697, 0.02557544757033248, 0.109375, 0.02557544757033248, 0.537117903930131, 0.02557544757033248, 0.027649769585253458, 0.24338624338624337, 0.027649769585253458, 0.02557544757033248, 0.02557544757033248, 0.28061224489795916, 0.537117903930131, 0.02557544757033248, 0.6888888888888889, 0.11594202898550725, 0.02557544757033248, 0.02557544757033248, 0.18604651162790697, 0.2643171806167401, 0.23404255319148937, 0.02557544757033248, 0.0546875, 0.0546875, 0.8461538461538461, 0.28061224489795916, 0.02557544757033248, 0.109375, 0.02557544757033248, 0.109375, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.0546875, 0.11594202898550725, 0.537117903930131, 0.7926829268292683, 0.18604651162790697, 0.28061224489795916, 0.02557544757033248, 0.02557544757033248, 0.18604651162790697, 0.027649769585253458, 0.02557544757033248, 0.6888888888888889, 0.109375, 0.2643171806167401, 0.28061224489795916, 0.0546875, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.18604651162790697, 0.2643171806167401, 0.537117903930131, 0.11594202898550725, 0.39864864864864863, 0.24338624338624337, 0.28061224489795916, 0.02557544757033248, 0.7926829268292683, 0.18604651162790697, 0.2643171806167401, 0.2643171806167401, 0.537117903930131, 0.02557544757033248, 0.7926829268292683, 0.02557544757033248, 0.02557544757033248, 0.0, 0.02557544757033248, 0.18604651162790697, 0.24338624338624337, 0.537117903930131, 0.02557544757033248, 0.23404255319148937, 0.28061224489795916, 0.7926829268292683, 0.02557544757033248, 0.24338624338624337, 0.537117903930131, 0.24338624338624337, 0.02557544757033248, 0.02557544757033248, 0.0, 0.02557544757033248, 0.28061224489795916, 0.02557544757033248, 0.537117903930131, 0.0546875, 0.28061224489795916, 0.02557544757033248, 0.18604651162790697, 0.02557544757033248, 0.28061224489795916, 0.02557544757033248, 0.11594202898550725, 0.39864864864864863, 0.027649769585253458, 0.39864864864864863, 0.2643171806167401, 0.24338624338624337, 0.109375, 0.02557544757033248, 0.0546875, 0.02557544757033248, 0.02557544757033248, 0.0546875, 0.18604651162790697, 0.02557544757033248, 0.24338624338624337, 0.28061224489795916, 0.0546875, 0.02557544757033248, 0.02557544757033248, 0.027649769585253458, 0.02557544757033248, 0.3076923076923077, 0.24338624338624337, 0.18604651162790697, 0.39864864864864863, 0.02557544757033248, 0.18604651162790697, 0.02557544757033248, 0.027649769585253458, 0.02557544757033248, 0.109375, 0.24338624338624337, 0.02557544757033248, 0.24338624338624337, 0.39864864864864863, 0.02557544757033248, 0.18604651162790697, 0.18604651162790697, 0.2643171806167401, 0.24338624338624337, 0.28061224489795916, 0.7926829268292683, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.2643171806167401, 0.02557544757033248, 0.02557544757033248, 0.6888888888888889, 0.24338624338624337, 0.02557544757033248, 0.28061224489795916, 0.537117903930131, 0.0546875, 0.02557544757033248, 0.2643171806167401, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.537117903930131, 0.109375, 0.02557544757033248, 0.537117903930131, 0.109375, 0.02557544757033248, 0.02557544757033248, 0.3076923076923077, 0.02557544757033248, 0.0546875, 0.02557544757033248, 0.0546875, 0.39864864864864863, 0.02557544757033248, 0.02557544757033248, 0.39864864864864863, 0.0546875, 0.28061224489795916, 0.18604651162790697, 0.0546875, 0.0546875, 1.0, 0.02557544757033248, 0.2643171806167401, 0.2643171806167401, 0.027649769585253458, 0.24338624338624337, 0.28061224489795916, 0.8461538461538461, 0.18604651162790697, 0.0546875, 0.6888888888888889, 0.02557544757033248, 0.18604651162790697, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.02557544757033248, 0.0 ...
